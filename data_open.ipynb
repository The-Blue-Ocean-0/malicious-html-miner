# %%
import pandas as pd

# %%
df = pd.read_csv('data/results/urls_data_with_batches.csv', nrows=10_000)  # 先頭から10万行だけ読み込む
# Out:
# C:\Users\taka2\AppData\Local\Temp\ipykernel_4804\3425397638.py:1: DtypeWarning: Columns (15,16,18,19,20,21,23,24,26,27,28,29,31,32,34,35,36,39,40,42,43,44,47,48,50,51,52,53,55,56,58,59,60,61,63,64,66,67,68,69,71,72,74,75,76,77,79,80,82,83,84,85,87,88,90,91,92,93,4231,4234,4235,4236,4239,4240,4242,4243,4244,4247,4250,4251,4252,4255,4256,4258,4259,4260,4263,4264,4266,4267,4268,4271,4272,4274,4275,4276,4279,4280,4282,4283,4284,4287,4288,4290,4291,4292,4311,4314,4315,4316,4323,4324,4335,4338,4339,4340,4347,4348,4527,4528,4530,4531,4532) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/results/urls_data_with_batches.csv', nrows=10_000)  # 先頭から10万行だけ読み込む

# %%
df.head()
# Out:
#                                                  url        type  \
# 0                                   br-icloud.com.br    phishing
# 1                mp3raid.com/music/krizz_kaliko.html      benign
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3  http://garage-pirenne.be/index.php?option=com_...  defacement
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement
#
#                                         original_url  url_type  url_len  \
# 0                                   br-icloud.com.br         2       16
# 1                mp3raid.com/music/krizz_kaliko.html         0       35
# 2                    bopsecrets.org/rexroth/cr/1.htm         0       31
# 3  http://www.garage-pirenne.be/index.php?option=...         1       77
# 4  http://adventure-nicaragua.net/index.php?optio...         1      228
#
#                 pri_domain  letters_count  digits_count  special_chars_count  \
# ...
